# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Funcs

# %%
def generate_ibm_hr_dataset(n_samples=1_000_000, seed=42):
    """
    Gera um dataset sintético inspirado no IBM HR Analytics com relações mais realistas

    Parameters:
    n_samples (int): Número de amostras a gerar
    seed (int): Seed para reprodutibilidade

    Returns:
    pd.DataFrame: Dataset gerado
    """
    np.random.seed(seed)

    # Gerando dados base
    data = {}

    # Idade com distribuição mais realista (concentrada entre 25-50 anos)
    data['Age'] = np.random.normal(38, 10, n_samples).astype(int)
    data['Age'] = np.clip(data['Age'], 18, 65)

    # Gênero
    data['Gender'] = np.random.choice(['Female', 'Male'], n_samples, p=[0.4, 0.6])

    # Educação (1-5: Below College, College, Bachelor, Master, Doctor)
    education_probs = [0.05, 0.15, 0.40, 0.30, 0.10]
    data['Education'] = np.random.choice([1, 2, 3, 4, 5], n_samples, p=education_probs)

    # Campo educacional baseado no nível de educação
    education_fields = ['Life Sciences', 'Other', 'Medical', 'Marketing', 'Technical Degree', 'Human Resources']
    data['EducationField'] = np.random.choice(education_fields, n_samples)

    # Departamento
    dept_probs = [0.45, 0.40, 0.15]  # Sales mais comum, HR menos comum
    data['Department'] = np.random.choice(['Sales', 'Research & Development', 'Human Resources'],
                                        n_samples, p=dept_probs)

    # Job Role baseado no departamento
    job_roles = {
        'Sales': ['Sales Executive', 'Sales Representative', 'Manager'],
        'Research & Development': ['Research Scientist', 'Laboratory Technician', 'Research Director', 'Manager'],
        'Human Resources': ['Human Resources', 'Manager']
    }

    data['JobRole'] = np.empty(n_samples, dtype=object)
    for dept in job_roles:
        mask = np.array(data['Department']) == dept
        n_dept = mask.sum()
        if n_dept > 0:
            data['JobRole'][mask] = np.random.choice(job_roles[dept], n_dept)

    # Job Level correlacionado com idade e educação
    base_level = np.ones(n_samples)
    age_bonus = (np.array(data['Age']) - 18) / 47 * 2  # 0-2 pontos baseado na idade
    edu_bonus = (np.array(data['Education']) - 1) / 4 * 2  # 0-2 pontos baseado na educação

    data['JobLevel'] = np.round(base_level + age_bonus + edu_bonus).astype(int)
    data['JobLevel'] = np.clip(data['JobLevel'], 1, 5)

    # Total Working Years correlacionado com idade
    data['TotalWorkingYears'] = np.maximum(0, data['Age'] - 18 - np.random.randint(0, 5, n_samples))

    # Years at Company (não pode ser maior que TotalWorkingYears)
    data['YearsAtCompany'] = np.random.randint(0, 21, n_samples)
    data['YearsAtCompany'] = np.minimum(data['YearsAtCompany'], data['TotalWorkingYears'])

    # Years in Current Role (não pode ser maior que YearsAtCompany)
    data['YearsInCurrentRole'] = np.random.randint(0, 11, n_samples)
    data['YearsInCurrentRole'] = np.minimum(data['YearsInCurrentRole'], data['YearsAtCompany'])

    # Years Since Last Promotion
    data['YearsSinceLastPromotion'] = np.random.randint(0, 8, n_samples)
    data['YearsSinceLastPromotion'] = np.minimum(data['YearsSinceLastPromotion'], data['YearsAtCompany'])

    # Years With Current Manager
    data['YearsWithCurrManager'] = np.random.randint(0, 8, n_samples)
    data['YearsWithCurrManager'] = np.minimum(data['YearsWithCurrManager'], data['YearsInCurrentRole'])

    # Número de empresas trabalhadas (correlacionado com anos totais de trabalho)
    max_companies = np.minimum(data['TotalWorkingYears'] // 2, 9)
    data['NumCompaniesWorked'] = np.array([np.random.randint(0, max(1, mc) + 1) for mc in max_companies])

    # Monthly Income correlacionado com JobLevel, Education e TotalWorkingYears
    base_income = 2000
    level_factor = data['JobLevel'] * 2000
    education_factor = data['Education'] * 500
    experience_factor = data['TotalWorkingYears'] * 100
    noise = np.random.normal(0, 1000, n_samples)

    data['MonthlyIncome'] = base_income + level_factor + education_factor + experience_factor + noise
    data['MonthlyIncome'] = np.clip(data['MonthlyIncome'].astype(int), 1000, 20000)

    # Rates
    data['DailyRate'] = np.random.randint(100, 1500, n_samples)
    data['HourlyRate'] = np.random.randint(30, 100, n_samples)
    data['MonthlyRate'] = np.random.randint(2000, 27000, n_samples)

    # Distance from home (distribuição exponencial - mais pessoas moram perto)
    data['DistanceFromHome'] = np.random.exponential(7, n_samples).astype(int) + 1
    data['DistanceFromHome'] = np.clip(data['DistanceFromHome'], 1, 29)

    # Business Travel
    travel_probs = [0.70, 0.20, 0.10]  # Maioria viaja raramente
    data['BusinessTravel'] = np.random.choice(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'],
                                            n_samples, p=travel_probs)

    # Satisfação e envolvimento
    data['EnvironmentSatisfaction'] = np.random.choice([1, 2, 3, 4], n_samples, p=[0.10, 0.20, 0.40, 0.30])
    data['JobSatisfaction'] = np.random.choice([1, 2, 3, 4], n_samples, p=[0.10, 0.20, 0.40, 0.30])
    data['RelationshipSatisfaction'] = np.random.choice([1, 2, 3, 4], n_samples, p=[0.10, 0.20, 0.40, 0.30])
    data['JobInvolvement'] = np.random.choice([1, 2, 3, 4], n_samples, p=[0.05, 0.15, 0.50, 0.30])
    data['WorkLifeBalance'] = np.random.choice([1, 2, 3, 4], n_samples, p=[0.10, 0.25, 0.45, 0.20])

    # Performance Rating (maioria boa performance)
    data['PerformanceRating'] = np.random.choice([3, 4], n_samples, p=[0.84, 0.16])

    # Percent Salary Hike correlacionado com Performance Rating
    data['PercentSalaryHike'] = np.where(
        data['PerformanceRating'] == 4,
        np.random.randint(15, 26, n_samples),
        np.random.randint(11, 18, n_samples)
    )

    # Stock Option Level correlacionado com JobLevel
    data['StockOptionLevel'] = np.random.choice([0, 1, 2, 3], n_samples,
                                               p=[0.40, 0.35, 0.20, 0.05])
    high_level_mask = data['JobLevel'] >= 4
    data['StockOptionLevel'][high_level_mask] = np.random.choice([1, 2, 3],
                                                                 high_level_mask.sum(),
                                                                 p=[0.30, 0.50, 0.20])

    # Training Times Last Year
    data['TrainingTimesLastYear'] = np.random.choice([0, 1, 2, 3, 4, 5, 6], n_samples,
                                                    p=[0.05, 0.10, 0.25, 0.30, 0.20, 0.08, 0.02])

    # Marital Status
    data['MaritalStatus'] = np.random.choice(['Single', 'Married', 'Divorced'], n_samples,
                                           p=[0.32, 0.55, 0.13])

    # OverTime - maior probabilidade para níveis menores e pessoas mais jovens
    overtime_base_prob = 0.28
    age_factor = (65 - data['Age']) / 47 * 0.1  # Jovens trabalham mais overtime
    level_factor = (5 - data['JobLevel']) / 4 * 0.1  # Níveis menores trabalham mais overtime

    overtime_prob = np.clip(overtime_base_prob + age_factor + level_factor, 0.1, 0.5)
    data['OverTime'] = [np.random.choice(['Yes', 'No'], p=[p, 1-p]) for p in overtime_prob]

    # Attrition - baseado em múltiplos fatores
    attrition_score = np.zeros(n_samples)

    # Fatores que aumentam attrition
    attrition_score += (data['JobSatisfaction'] == 1) * 0.15
    attrition_score += (data['EnvironmentSatisfaction'] == 1) * 0.10
    attrition_score += (data['WorkLifeBalance'] == 1) * 0.10
    attrition_score += (np.array(data['OverTime']) == 'Yes') * 0.08
    attrition_score += (data['YearsSinceLastPromotion'] > 5) * 0.05
    attrition_score += (data['DistanceFromHome'] > 20) * 0.05
    attrition_score += (np.array(data['MaritalStatus']) == 'Single') * 0.03
    attrition_score += (data['NumCompaniesWorked'] > 5) * 0.04

    # Fatores que diminuem attrition
    attrition_score -= (data['JobLevel'] >= 4) * 0.10
    attrition_score -= (data['YearsAtCompany'] > 10) * 0.08
    attrition_score -= (data['StockOptionLevel'] > 0) * 0.05

    # Probabilidade base de 16%
    attrition_prob = np.clip(0.16 + attrition_score, 0.05, 0.50)
    data['Attrition'] = [np.random.choice(['Yes', 'No'], p=[p, 1-p]) for p in attrition_prob]

    # Campos fixos
    data['EmployeeCount'] = np.ones(n_samples, dtype=int)
    data['EmployeeNumber'] = np.arange(1, n_samples + 1)
    data['Over18'] = ['Y'] * n_samples
    data['StandardHours'] = [80] * n_samples

    # Criar DataFrame
    df = pd.DataFrame(data)

    # Reordenar colunas para match com o dataset original
    column_order = [
        'Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
        'YearsWithCurrManager'
    ]

    return df[column_order]

# %% [markdown]
# # Basico

# %%
df = generate_ibm_hr_dataset(n_samples=1_000_000, seed=42)

# %%
df.to_csv('../data/ibm_hr_dataset.csv', index=False)

# %% [markdown]
# ## Exibir as primeiras linhas do dataset

# %%
df
# Out:
#         Age Attrition     BusinessTravel  DailyRate              Department  \
# 0        42        No      Travel_Rarely        575  Research & Development
# 1        36        No      Travel_Rarely        535         Human Resources
# 2        44        No      Travel_Rarely        286  Research & Development
# 3        53       Yes  Travel_Frequently        746                   Sales
# 4        35        No      Travel_Rarely        408  Research & Development
# ...     ...       ...                ...        ...                     ...
# 999995   42        No      Travel_Rarely        262  Research & Development
# 999996   39       Yes      Travel_Rarely        340                   Sales
# 999997   36        No  Travel_Frequently        777                   Sales
# 999998   52       Yes      Travel_Rarely       1148         Human Resources
# 999999   42        No  Travel_Frequently       1388         Human Resources
#
#         DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                      1          3         Marketing              1
# 1                      2          4   Human Resources              1
# 2                      2          4           Medical              1
# 3                     11          2           Medical              1
# 4                      7          5  Technical Degree              1
# ...                  ...        ...               ...            ...
# 999995                10          4     Life Sciences              1
# 999996                20          3     Life Sciences              1
# 999997                15          4         Marketing              1
# 999998                 2          3   Human Resources              1
# 999999                29          3         Marketing              1
#
#         EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                    1  ...                         2            80
# 1                    2  ...                         4            80
# 2                    3  ...                         1            80
# 3                    4  ...                         4            80
# 4                    5  ...                         2            80
# ...                ...  ...                       ...           ...
# 999995          999996  ...                         4            80
# 999996          999997  ...                         4            80
# 999997          999998  ...                         4            80
# 999998          999999  ...                         2            80
# 999999         1000000  ...                         4            80
#
#         StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                      1                 24                      3
# 1                      1                 18                      5
# 2                      2                 22                      3
# 3                      0                 31                      1
# 4                      1                 17                      2
# ...                  ...                ...                    ...
# 999995                 1                 20                      3
# 999996                 1                 18                      6
# 999997                 2                 16                      4
# 999998                 1                 31                      4
# 999999                 1                 20                      0
#
#        WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                    4               5                  0
# 1                    2              17                  8
# 2                    3              20                  0
# 3                    3               3                  3
# 4                    1              14                  5
# ...                ...             ...                ...
# 999995               4               6                  4
# 999996               3              14                 10
# 999997               4               9                  2
# 999998               1              18                  0
# 999999               2               2                  2
#
#         YearsSinceLastPromotion  YearsWithCurrManager
# 0                             3                     0
# 1                             7                     3
# 2                             1                     0
# 3                             0                     3
# 4                             3                     5
# ...                         ...                   ...
# 999995                        6                     4
# 999996                        2                     3
# 999997                        6                     1
# 999998                        4                     0
# 999999                        2                     2
#
# [1000000 rows x 35 columns]

# %% [markdown]
# ## Exibir estatísticas descritivas do dataset

# %%
df.describe().T
# Out:
#                               count           mean            std     min  \
# Age                       1000000.0      37.573109       9.752131    18.0
# DailyRate                 1000000.0     800.110722     404.135932   100.0
# DistanceFromHome          1000000.0       7.389395       6.487020     1.0
# Education                 1000000.0       3.250821       0.993399     1.0
# EmployeeCount             1000000.0       1.000000       0.000000     1.0
# EmployeeNumber            1000000.0  500000.500000  288675.278932     1.0
# EnvironmentSatisfaction   1000000.0       2.898258       0.944161     1.0
# HourlyRate                1000000.0      64.528856      20.204914    30.0
# JobInvolvement            1000000.0       3.050033       0.803532     1.0
# JobLevel                  1000000.0       2.960664       0.700052     1.0
# JobSatisfaction           1000000.0       2.900421       0.943386     1.0
# MonthlyIncome             1000000.0   11311.698693    2585.337246  1258.0
# MonthlyRate               1000000.0   14504.885874    7210.287533  2000.0
# NumCompaniesWorked        1000000.0       3.437956       2.749722     0.0
# PercentSalaryHike         1000000.0      14.960437       3.132714    11.0
# PerformanceRating         1000000.0       3.160585       0.367148     3.0
# RelationshipSatisfaction  1000000.0       2.900015       0.942661     1.0
# StandardHours             1000000.0      80.000000       0.000000    80.0
# StockOptionLevel          1000000.0       1.104926       0.943522     0.0
# TotalWorkingYears         1000000.0      17.646932       9.711037     0.0
# TrainingTimesLastYear     1000000.0       2.818794       1.328194     0.0
# WorkLifeBalance           1000000.0       2.750494       0.886850     1.0
# YearsAtCompany            1000000.0       8.291746       5.723518     0.0
# YearsInCurrentRole        1000000.0       3.712092       2.980426     0.0
# YearsSinceLastPromotion   1000000.0       2.792037       2.236920     0.0
# YearsWithCurrManager      1000000.0       2.084859       1.952559     0.0
#
#                                 25%       50%        75%        max
# Age                           31.00      37.0      44.00       65.0
# DailyRate                    451.00     800.0    1150.00     1499.0
# DistanceFromHome               3.00       5.0      10.00       29.0
# Education                      3.00       3.0       4.00        5.0
# EmployeeCount                  1.00       1.0       1.00        1.0
# EmployeeNumber            250000.75  500000.5  750000.25  1000000.0
# EnvironmentSatisfaction        2.00       3.0       4.00        4.0
# HourlyRate                    47.00      65.0      82.00       99.0
# JobInvolvement                 3.00       3.0       4.00        4.0
# JobLevel                       3.00       3.0       3.00        5.0
# JobSatisfaction                2.00       3.0       4.00        4.0
# MonthlyIncome               9612.00   11336.0   12929.00    20000.0
# MonthlyRate                 8266.00   14516.0   20745.00    26999.0
# NumCompaniesWorked             1.00       3.0       6.00        9.0
# PercentSalaryHike             13.00      15.0      17.00       25.0
# PerformanceRating              3.00       3.0       3.00        4.0
# RelationshipSatisfaction       2.00       3.0       4.00        4.0
# StandardHours                 80.00      80.0      80.00       80.0
# StockOptionLevel               0.00       1.0       2.00        3.0
# TotalWorkingYears             11.00      17.0      24.00       47.0
# TrainingTimesLastYear          2.00       3.0       4.00        6.0
# WorkLifeBalance                2.00       3.0       3.00        4.0
# YearsAtCompany                 3.00       8.0      13.00       20.0
# YearsInCurrentRole             1.00       3.0       6.00       10.0
# YearsSinceLastPromotion        1.00       2.0       5.00        7.0
# YearsWithCurrManager           0.00       2.0       3.00        7.0

# %%
df.describe()
# Out:
#                   Age       DailyRate  DistanceFromHome       Education  \
# count  1000000.000000  1000000.000000    1000000.000000  1000000.000000
# mean        37.573109      800.110722          7.389395        3.250821
# std          9.752131      404.135932          6.487020        0.993399
# min         18.000000      100.000000          1.000000        1.000000
# 25%         31.000000      451.000000          3.000000        3.000000
# 50%         37.000000      800.000000          5.000000        3.000000
# 75%         44.000000     1150.000000         10.000000        4.000000
# max         65.000000     1499.000000         29.000000        5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction      HourlyRate  \
# count      1000000.0  1000000.000000           1000000.000000  1000000.000000
# mean             1.0   500000.500000                 2.898258       64.528856
# std              0.0   288675.278932                 0.944161       20.204914
# min              1.0        1.000000                 1.000000       30.000000
# 25%              1.0   250000.750000                 2.000000       47.000000
# 50%              1.0   500000.500000                 3.000000       65.000000
# 75%              1.0   750000.250000                 4.000000       82.000000
# max              1.0  1000000.000000                 4.000000       99.000000
#
#        JobInvolvement        JobLevel  ...  RelationshipSatisfaction  \
# count  1000000.000000  1000000.000000  ...            1000000.000000
# mean         3.050033        2.960664  ...                  2.900015
# std          0.803532        0.700052  ...                  0.942661
# min          1.000000        1.000000  ...                  1.000000
# 25%          3.000000        3.000000  ...                  2.000000
# 50%          3.000000        3.000000  ...                  3.000000
# 75%          4.000000        3.000000  ...                  4.000000
# max          4.000000        5.000000  ...                  4.000000
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count      1000000.0    1000000.000000     1000000.000000
# mean            80.0          1.104926          17.646932
# std              0.0          0.943522           9.711037
# min             80.0          0.000000           0.000000
# 25%             80.0          0.000000          11.000000
# 50%             80.0          1.000000          17.000000
# 75%             80.0          2.000000          24.000000
# max             80.0          3.000000          47.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count         1000000.000000   1000000.000000  1000000.000000
# mean                2.818794         2.750494        8.291746
# std                 1.328194         0.886850        5.723518
# min                 0.000000         1.000000        0.000000
# 25%                 2.000000         2.000000        3.000000
# 50%                 3.000000         3.000000        8.000000
# 75%                 4.000000         3.000000       13.000000
# max                 6.000000         4.000000       20.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count      1000000.000000           1000000.000000        1000000.000000
# mean             3.712092                 2.792037              2.084859
# std              2.980426                 2.236920              1.952559
# min              0.000000                 0.000000              0.000000
# 25%              1.000000                 1.000000              0.000000
# 50%              3.000000                 2.000000              2.000000
# 75%              6.000000                 5.000000              3.000000
# max             10.000000                 7.000000              7.000000
#
# [8 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   Age                       1000000 non-null  int64
#  1   Attrition                 1000000 non-null  object
#  2   BusinessTravel            1000000 non-null  object
#  3   DailyRate                 1000000 non-null  int64
#  4   Department                1000000 non-null  object
#  5   DistanceFromHome          1000000 non-null  int64
#  6   Education                 1000000 non-null  int64
#  7   EducationField            1000000 non-null  object
#  8   EmployeeCount             1000000 non-null  int64
#  9   EmployeeNumber            1000000 non-null  int64
#  10  EnvironmentSatisfaction   1000000 non-null  int64
#  11  Gender                    1000000 non-null  object
#  12  HourlyRate                1000000 non-null  int64
#  13  JobInvolvement            1000000 non-null  int64
#  14  JobLevel                  1000000 non-null  int64
#  15  JobRole                   1000000 non-null  object
#  16  JobSatisfaction           1000000 non-null  int64
#  17  MaritalStatus             1000000 non-null  object
#  18  MonthlyIncome             1000000 non-null  int64
#  19  MonthlyRate               1000000 non-null  int64
#  20  NumCompaniesWorked        1000000 non-null  int64
#  21  Over18                    1000000 non-null  object
#  22  OverTime                  1000000 non-null  object
#  23  PercentSalaryHike         1000000 non-null  int64
#  24  PerformanceRating         1000000 non-null  int64
#  25  RelationshipSatisfaction  1000000 non-null  int64
#  26  StandardHours             1000000 non-null  int64
#  27  StockOptionLevel          1000000 non-null  int64
#  28  TotalWorkingYears         1000000 non-null  int64
#  29  TrainingTimesLastYear     1000000 non-null  int64
#  30  WorkLifeBalance           1000000 non-null  int64
#  31  YearsAtCompany            1000000 non-null  int64
#  32  YearsInCurrentRole        1000000 non-null  int64
#  33  YearsSinceLastPromotion   1000000 non-null  int64
#  34  YearsWithCurrManager      1000000 non-null  int64
# dtypes: int64(26), object(9)
# memory usage: 267.0+ MB

# %% [markdown]
# ## Exibir a distribuição da variável alvo

# %%
df['Attrition'].value_counts(normalize=True)
# Out:
# Attrition
# No     0.821159
# Yes    0.178841
# Name: proportion, dtype: float64

# %% [markdown]
# # EDA

# %% [markdown]
# ## Correlação

# %% [markdown]
# ### Var numericas

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
print(f"=== VARIÁVEIS NUMÉRICAS ({len(numeric_cols)}) ===")
print(numeric_cols.tolist())
# Out:
# === VARIÁVEIS NUMÉRICAS (26) ===
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
plt.figure(figsize=(20, 16))
correlation_matrix = df[numeric_cols].corr()

mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
sns.heatmap(correlation_matrix, mask=mask, annot=True, fmt='.2f', cmap='coolwarm',
            square=True, linewidths=0.5, cbar_kws={"shrink": 0.8})

plt.title('Matriz de Correlação das Variáveis Numéricas', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Var categoricas

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
categorical_cols
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
crosstab = pd.crosstab(df['DistanceFromHome'], df['Attrition'])
crosstab
# Out:
# Attrition             No    Yes
# DistanceFromHome
# 1                 109883  23540
# 2                  94961  20438
# 3                  82055  17501
# 4                  71501  15192
# 5                  62285  13117
# 6                  54030  11490
# 7                  46685   9965
# 8                  39949   8715
# 9                  34883   7583
# 10                 30275   6474
# 11                 26325   5650
# 12                 22859   4943
# 13                 19581   4185
# 14                 17174   3685
# 15                 14586   3288
# 16                 12829   2708
# 17                 11152   2390
# 18                  9726   2068
# 19                  8241   1855
# 20                  7181   1512
# 21                  6077   1648
# 22                  5178   1458
# 23                  4538   1223
# 24                  3895   1152
# 25                  3342    927
# 26                  2968    819
# 27                  2540    706
# 28                  2210    635
# 29                 14250   3974

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.ravel()

important_cats = ['Department', 'JobRole', 'MaritalStatus', 'OverTime', 'BusinessTravel', 'Gender']

for idx, col in enumerate(important_cats):
    crosstab = pd.crosstab(df[col], df['Attrition'])
    crosstab_pct = crosstab.div(crosstab.sum(axis=1), axis=0) * 100

    crosstab_pct.plot(kind='bar', ax=axes[idx], stacked=True, color=['#2ecc71', '#e74c3c'])
    axes[idx].set_title(f'Attrition por {col}')
    axes[idx].set_ylabel('Percentual')
    axes[idx].legend(['No', 'Yes'], loc='upper right')
    axes[idx].set_xticklabels(axes[idx].get_xticklabels(), rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribuição de Idade, Salário, Anos na Empresa

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
sns.histplot(data=df, x="Age", hue="Attrition", kde=True, ax=axes[0], element="step", stat="density", common_norm=False)
axes[0].set_title('Distribuição de Idade por Attrition')

sns.histplot(data=df, x="MonthlyIncome", hue="Attrition", kde=True, ax=axes[1], element="step", stat="density", common_norm=False)
axes[1].set_title('Distribuição de Salário Mensal por Attrition')

sns.histplot(data=df, x="YearsAtCompany", hue="Attrition", kde=True, ax=axes[2], element="step", stat="density", common_norm=False)
axes[2].set_title('Distribuição de Anos na Empresa por Attrition')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Boxplots de Salário, Idade, Distância

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
sns.boxplot(data=df, x="Attrition", y="MonthlyIncome", ax=axes[0])
axes[0].set_title('Salário Mensal por Attrition')

sns.boxplot(data=df, x="Attrition", y="Age", ax=axes[1])
axes[1].set_title('Idade por Attrition')

sns.boxplot(data=df, x="Attrition", y="DistanceFromHome", ax=axes[2])
axes[2].set_title('Distância de Casa por Attrition')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Attrition vs Satisfação

# %%
satisf_vars = ['JobSatisfaction', 'EnvironmentSatisfaction', 'RelationshipSatisfaction']
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
for i, var in enumerate(satisf_vars):
    sns.boxplot(data=df, x="Attrition", y=var, ax=axes[i])
    axes[i].set_title(f'{var} por Attrition')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  Matriz de Confusão de Features Categóricas (Department x OverTime)

# %%
pivot = pd.crosstab(df['Department'], df['OverTime'], values=(df['Attrition'] == 'Yes'), aggfunc=np.mean).fillna(0)
plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, fmt=".2f", cmap="coolwarm")
plt.title('Percentual de Attrition por Departamento e OverTime')
plt.ylabel('Departamento')
plt.xlabel('OverTime')
plt.show()
# Out:
# /tmp/ipykernel_2380266/1974017600.py:1: FutureWarning: The provided callable <function mean at 0x7faa10480310> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot = pd.crosstab(df['Department'], df['OverTime'], values=(df['Attrition'] == 'Yes'), aggfunc=np.mean).fillna(0)

# %% [markdown]
# # Features professor

# %%
# Ratio de salário vs anos de experiência
df['IncomePerYear'] = df['MonthlyIncome'] / (df['TotalWorkingYears'] + 1)

# Satisfação total (média de todas as satisfações)
satisfaction_cols = ['EnvironmentSatisfaction', 'JobSatisfaction', 'RelationshipSatisfaction']
df['TotalSatisfaction'] = df[satisfaction_cols].mean(axis=1)

# Anos sem promoção em relação aos anos na empresa
df['PromotionRate'] = df['YearsSinceLastPromotion'] / (df['YearsAtCompany'] + 1)

# Indicador se trabalha há muito tempo sem promoção
df['LongTimeNoPromotion'] = (df['YearsSinceLastPromotion'] > 5).astype(int)

# Idade quando começou a trabalhar
df['AgeStartedWorking'] = df['Age'] - df['TotalWorkingYears']
df['AgeStartedWorking'] = df.loc[df['AgeStartedWorking'] > 14,'AgeStartedWorking']
# Número de anos em outras empresas
df['YearsInOtherCompanies'] = df['TotalWorkingYears'] - df['YearsAtCompany']

# Taxa de mudança de empresa
df['CompanyChangeRate'] = df['NumCompaniesWorked'] / (df['TotalWorkingYears'] + 1)

print(f"Novas features criadas:{['IncomePerYear', 'TotalSatisfaction', 'PromotionRate', 'LongTimeNoPromotion','AgeStartedWorking', 'YearsInOtherCompanies', 'CompanyChangeRate']}")
# Out:
# Novas features criadas:['IncomePerYear', 'TotalSatisfaction', 'PromotionRate', 'LongTimeNoPromotion', 'AgeStartedWorking', 'YearsInOtherCompanies', 'CompanyChangeRate']

# %% [markdown]
# # Features novas

# %% [markdown]
# ## Anos no mesmo cargo sem promoção
#     Pode descrever se a pessoa está estagnada no mesmo cargo.

# %%
df['AnosCargoSemPromocao'] = df['YearsInCurrentRole'] - df['YearsSinceLastPromotion']
# Corrigir negativos para zero
df['AnosCargoSemPromocao'] = df['AnosCargoSemPromocao'].clip(lower=0)
df['AnosCargoSemPromocao'].value_counts(normalize=True) * 100
# Out:
# AnosCargoSemPromocao
# 0     55.0790
# 1      9.2551
# 2      8.2962
# 3      7.2864
# 4      5.9109
# 5      4.6767
# 6      3.5853
# 7      2.6095
# 8      1.7789
# 9      1.0568
# 10     0.4652
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x="AnosCargoSemPromocao", hue="Attrition", multiple="dodge", shrink=0.8, discrete=True)
plt.title('Distribuição de AnosCargoSemPromocao por Attrition')
plt.xlabel('AnosCargoSemPromocao')
plt.ylabel('Número de Funcionários')
plt.show()

# %% [markdown]
# ## Interação OverTime e JobLevel
#     Funcionários em cargos altos que fazem muito OverTime podem estar sob risco diferente dos cargos mais baixos

# %%
df['CargoAlto_HorasExtras'] = ((df['JobLevel'] > 3) & (df['OverTime'] == 'Yes')).astype(int)
df['CargoAlto_HorasExtras'].value_counts(normalize=True) * 100
# Out:
# CargoAlto_HorasExtras
# 0    93.0041
# 1     6.9959
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x="CargoAlto_HorasExtras", hue="Attrition")
plt.title('Distribuição de CargoAlto_HorasExtras por Attrition')
plt.xlabel('CargoAlto_HorasExtras')
plt.ylabel('Número de Funcionários')
plt.show()

# %% [markdown]
# ## Score de estabilidade
#     Pessoas que mudam muito de empresa tendem a sair mais

# %%
anos_de_carreira = df['Age'] - df['AgeStartedWorking'] + 1
df['ScoreEstab_Carreira'] = 1 / ( (df['NumCompaniesWorked'] / anos_de_carreira) + 1 )
df['ScoreEstab_Carreira'].value_counts(normalize=True) * 100
# Out:
# ScoreEstab_Carreira
# 1.000000    16.3321
# 0.750000     4.1417
# 0.800000     3.5280
# 0.833333     2.6376
# 0.500000     2.3435
#              ...
# 0.979167     0.0087
# 0.921569     0.0085
# 0.872727     0.0078
# 0.979592     0.0078
# 0.905660     0.0061
# Name: proportion, Length: 228, dtype: float64

# %%
plt.figure(figsize=(8, 5))
df['ScoreEstabilidadeFormat'] = df['ScoreEstab_Carreira'].round(1)
sns.countplot(data=df, x="ScoreEstabilidadeFormat", hue="Attrition")
plt.title('Distribuição de ScoreEstabilidadeFaixa por Attrition')
plt.xlabel('ScoreEstabilidadeFaixa')
plt.ylabel('Número de Funcionários')
plt.show()

# %% [markdown]
# ## burnout
#     Quem tem alto OverTime, baixo WorkLifeBalance baixa satisfação como potencial burnout

# %%
df['Burnout'] = (
    (df['OverTime'] == 'Yes') &
    (df['WorkLifeBalance'] <= 2) &
    (df['TotalSatisfaction'] <= 2)
).astype(int)
df['Burnout'].value_counts(normalize=True) * 100
# Out:
# Burnout
# 0    98.6892
# 1     1.3108
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x="Burnout", hue="Attrition")
plt.title('Frequência de Burnout por Attrition')
plt.xlabel('Burnout (0 = Não, 1 = Sim)')
plt.ylabel('Número de Funcionários')
plt.show()

# %% [markdown]
# # Features Luc

# %% [markdown]
# ## Percentual de Anos na Empresa Atual

# %%
df['PercAnoEmpresaAtual'] = df['YearsAtCompany'] / (df['TotalWorkingYears'] + 1)
df['PercAnoEmpresaAtual']
# Out:
# 0         0.200000
# 1         0.894737
# 2         0.869565
# 3         0.093750
# 4         0.777778
#             ...
# 999995    0.285714
# 999996    0.736842
# 999997    0.529412
# 999998    0.562500
# 999999    0.095238
# Name: PercAnoEmpresaAtual, Length: 1000000, dtype: float64

# %% [markdown]
# ## Salario por tempo de casa

# %%
df['SalarioPorTempodeCasa'] = df['MonthlyIncome']/(df['YearsAtCompany']+1)
df['SalarioPorTempodeCasa']
# Out:
# 0         1896.666667
# 1          747.500000
# 2          662.761905
# 3         3050.250000
# 4          976.466667
#              ...
# 999995    1961.571429
# 999996     853.533333
# 999997    1201.100000
# 999998     713.210526
# 999999    3475.000000
# Name: SalarioPorTempodeCasa, Length: 1000000, dtype: float64

# %% [markdown]
# ## Treinamento por tempo de casa

# %%
df['TreinamentosPorTempodeCasa'] = df['TrainingTimesLastYear']/(df['YearsAtCompany']+1)
df['TreinamentosPorTempodeCasa']
# Out:
# 0         0.500000
# 1         0.277778
# 2         0.142857
# 3         0.250000
# 4         0.133333
#             ...
# 999995    0.428571
# 999996    0.400000
# 999997    0.400000
# 999998    0.210526
# 999999    0.000000
# Name: TreinamentosPorTempodeCasa, Length: 1000000, dtype: float64

# %% [markdown]
# ## Tempo Cargo Atual Pelo Tempo Total trabalhado

# %%
df['TempoCargoAtualPeloNivel'] = df['YearsInCurrentRole']/ (df['TotalWorkingYears'] + 1)
df['TempoCargoAtualPeloNivel']
# Out:
# 0         0.000000
# 1         0.421053
# 2         0.000000
# 3         0.093750
# 4         0.277778
#             ...
# 999995    0.190476
# 999996    0.526316
# 999997    0.117647
# 999998    0.000000
# 999999    0.095238
# Name: TempoCargoAtualPeloNivel, Length: 1000000, dtype: float64

# %% [markdown]
# ## Tempo Cargo Atual Pelo Nivel

# %%
df['TempoCargoAtualPeloNivel'] = df['YearsInCurrentRole']/ df['JobLevel']
df['TempoCargoAtualPeloNivel']
# Out:
# 0         0.000000
# 1         2.666667
# 2         0.000000
# 3         1.000000
# 4         1.250000
#             ...
# 999995    1.000000
# 999996    3.333333
# 999997    0.666667
# 999998    0.000000
# 999999    0.666667
# Name: TempoCargoAtualPeloNivel, Length: 1000000, dtype: float64

# %% [markdown]
# ## Tempo Sem Promoção Por Tempo Com Manager

# %%
df['TempSemPromoPorTempComManager'] = df['YearsSinceLastPromotion']/(df['YearsWithCurrManager']+1)
df['TempSemPromoPorTempComManager']
# Out:
# 0         3.000000
# 1         1.750000
# 2         1.000000
# 3         0.000000
# 4         0.500000
#             ...
# 999995    1.200000
# 999996    0.500000
# 999997    3.000000
# 999998    4.000000
# 999999    0.666667
# Name: TempSemPromoPorTempComManager, Length: 1000000, dtype: float64

# %% [markdown]
# ## Tempo com Gestor Atual em relação ao tempo na empresa

# %%
df['TempGestAtualPorTempodeCasa'] = df['YearsWithCurrManager']/ (df['YearsAtCompany']+1)
df['TempGestAtualPorTempodeCasa']
# Out:
# 0         0.000000
# 1         0.166667
# 2         0.000000
# 3         0.750000
# 4         0.333333
#             ...
# 999995    0.571429
# 999996    0.200000
# 999997    0.100000
# 999998    0.000000
# 999999    0.666667
# Name: TempGestAtualPorTempodeCasa, Length: 1000000, dtype: float64

# %% [markdown]
# ## Salário por Quilômetro

# %%
df['SalarioPorKm'] = df['MonthlyIncome']/ (df['DistanceFromHome'])
df['SalarioPorKm']
# Out:
# 0         11380.000000
# 1          6727.500000
# 2          6959.000000
# 3          1109.181818
# 4          2092.428571
#               ...
# 999995     1373.100000
# 999996      640.150000
# 999997      800.733333
# 999998     6775.500000
# 999999      359.482759
# Name: SalarioPorKm, Length: 1000000, dtype: float64

# %% [markdown]
# ## Salário por Nível de Educação

# %%
df['SalarioPorNivelEdu'] = df['MonthlyIncome']/ (df['Education'])
df['SalarioPorNivelEdu']
# Out:
# 0         3793.333333
# 1         3363.750000
# 2         3479.500000
# 3         6100.500000
# 4         2929.400000
#              ...
# 999995    3432.750000
# 999996    4267.666667
# 999997    3002.750000
# 999998    4517.000000
# 999999    3475.000000
# Name: SalarioPorNivelEdu, Length: 1000000, dtype: float64

# %% [markdown]
# ## Salário por SatisfaçãoMédia

# %%
df['SalarioPorSatisf'] = df['MonthlyIncome']/ (df['TotalSatisfaction'])
df['SalarioPorSatisf']
# Out:
# 0         4877.142857
# 1         4036.500000
# 2         8350.800000
# 3         3660.300000
# 4         7323.500000
#              ...
# 999995    4577.000000
# 999996    4801.125000
# 999997    4003.666667
# 999998    5081.625000
# 999999    3475.000000
# Name: SalarioPorSatisf, Length: 1000000, dtype: float64

# %% [markdown]
# # Features Vitor

# %% [markdown]
# ## PromotionsPerYear
#     Captura quão frequente são promoções — mais promoções em menos tempo, maior valor.

# %%
df['PromotionsPerYear'] = 1 / (df['YearsSinceLastPromotion'] + 1)
df['PromotionsPerYear']
# Out:
# 0         0.250000
# 1         0.125000
# 2         0.500000
# 3         1.000000
# 4         0.250000
#             ...
# 999995    0.142857
# 999996    0.333333
# 999997    0.142857
# 999998    0.200000
# 999999    0.333333
# Name: PromotionsPerYear, Length: 1000000, dtype: float64

# %% [markdown]
# ## CompaniesPerYear
#      Rotatividade externa: mais empresas em menos tempo.

# %%
df['CompaniesPerYear'] = df['NumCompaniesWorked'] / (df['TotalWorkingYears'] + 1)
df['CompaniesPerYear']
# Out:
# 0         0.280000
# 1         0.368421
# 2         0.217391
# 3         0.187500
# 4         0.388889
#             ...
# 999995    0.000000
# 999996    0.210526
# 999997    0.235294
# 999998    0.125000
# 999999    0.000000
# Name: CompaniesPerYear, Length: 1000000, dtype: float64

# %% [markdown]
# ## YearsInRolePercCompany
#      Indica se o colaborador está há muito tempo na mesma função.

# %%
df['YearsInRolePercCompany'] = df['YearsInCurrentRole'] / (df['YearsAtCompany'] + 1)
df['YearsInRolePercCompany']
# Out:
# 0         0.000000
# 1         0.444444
# 2         0.000000
# 3         0.750000
# 4         0.333333
#             ...
# 999995    0.571429
# 999996    0.666667
# 999997    0.200000
# 999998    0.000000
# 999999    0.666667
# Name: YearsInRolePercCompany, Length: 1000000, dtype: float64

# %% [markdown]
# ## SatisfacaoGeral

# %%
df['SatisfacaoGeral'] = (
    df['JobSatisfaction'] +
    df['EnvironmentSatisfaction'] +
    df['RelationshipSatisfaction'] +
    df['JobInvolvement']
) / 4
df['SatisfacaoGeral']
# Out:
# 0         2.50
# 1         3.25
# 2         1.75
# 3         3.50
# 4         1.75
#           ...
# 999995    3.25
# 999996    3.00
# 999997    3.00
# 999998    2.75
# 999999    2.50
# Name: SatisfacaoGeral, Length: 1000000, dtype: float64

# %% [markdown]
# ## SatisfacaoPeloNivel
#      Indica se a satisfação acompanha a senioridade.

# %%
df['SatisfacaoPeloNivel'] = df['SatisfacaoGeral'] / df['JobLevel']
df['SatisfacaoPeloNivel']
# Out:
# 0         0.833333
# 1         1.083333
# 2         0.437500
# 3         1.166667
# 4         0.437500
#             ...
# 999995    0.812500
# 999996    1.000000
# 999997    1.000000
# 999998    0.916667
# 999999    0.833333
# Name: SatisfacaoPeloNivel, Length: 1000000, dtype: float64

# %% [markdown]
# ## EstavelNaEmpresa
#  1 para funcionários estáveis (muito tempo e pouca troca de empresa).

# %%
df['EstavelNaEmpresa'] = ((df['YearsAtCompany'] > 5) & (df['NumCompaniesWorked'] <= 2)).astype(int)
df['EstavelNaEmpresa']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 999995    1
# 999996    0
# 999997    0
# 999998    0
# 999999    0
# Name: EstavelNaEmpresa, Length: 1000000, dtype: int64

# %% [markdown]
# ## TempoComGestorProporcao
#     →Quanto tempo com o atual gestor em relação ao tempo de empresa.

# %%
df['TempoComGestorProporcao'] = df['YearsWithCurrManager'] / (df['YearsAtCompany'] + 1)
df['TempoComGestorProporcao']
# Out:
# 0         0.000000
# 1         0.166667
# 2         0.000000
# 3         0.750000
# 4         0.333333
#             ...
# 999995    0.571429
# 999996    0.200000
# 999997    0.100000
# 999998    0.000000
# 999999    0.666667
# Name: TempoComGestorProporcao, Length: 1000000, dtype: float64

# %% [markdown]
# ## SalarioPorSatisfacaoGeral
#      Salário alto nem sempre representa satisfação — ajuda a capturar desalinhamentos.

# %%
df['SalarioPorSatisfacaoGeral'] = df['MonthlyIncome'] / (df['SatisfacaoGeral'] + 1)
df['SalarioPorSatisfacaoGeral']
# Out:
# 0         3251.428571
# 1         3165.882353
# 2         5061.090909
# 3         2711.333333
# 4         5326.181818
#              ...
# 999995    3230.823529
# 999996    3200.750000
# 999997    3002.750000
# 999998    3613.600000
# 999999    2978.571429
# Name: SalarioPorSatisfacaoGeral, Length: 1000000, dtype: float64

# %% [markdown]
# ## SalarioAjustadoPorCargo
#      Serve para comparar discrepâncias salariais dentro do mesmo nível.

# %%
df['SalarioAjustadoPorCargo'] = df['MonthlyIncome'] / (df['JobLevel'] + 1)
df['SalarioAjustadoPorCargo']
# Out:
# 0         2845.00
# 1         3363.75
# 2         2783.60
# 3         3050.25
# 4         2929.40
#            ...
# 999995    2746.20
# 999996    3200.75
# 999997    3002.75
# 999998    3387.75
# 999999    2606.25
# Name: SalarioAjustadoPorCargo, Length: 1000000, dtype: float64

# %% [markdown]
# # EDA 2,0

# %%
numeric_cols2 = df.select_dtypes(include=['int64', 'float64']).columns
numeric_cols2
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'IncomePerYear',
#        'TotalSatisfaction', 'PromotionRate', 'LongTimeNoPromotion',
#        'AgeStartedWorking', 'YearsInOtherCompanies', 'CompanyChangeRate',
#        'AnosCargoSemPromocao', 'CargoAlto_HorasExtras', 'ScoreEstab_Carreira',
#        'ScoreEstabilidadeFormat', 'Burnout', 'PercAnoEmpresaAtual',
#        'SalarioPorTempodeCasa', 'TreinamentosPorTempodeCasa',
#        'TempoCargoAtualPeloNivel', 'TempSemPromoPorTempComManager',
#        'TempGestAtualPorTempodeCasa', 'SalarioPorKm', 'SalarioPorNivelEdu',
#        'SalarioPorSatisf', 'PromotionsPerYear', 'CompaniesPerYear',
#        'YearsInRolePercCompany', 'SatisfacaoGeral', 'SatisfacaoPeloNivel',
#        'EstavelNaEmpresa', 'TempoComGestorProporcao',
#        'SalarioPorSatisfacaoGeral', 'SalarioAjustadoPorCargo'],
#       dtype='object')

# %%
features_novas = list(set(numeric_cols2) - set(numeric_cols)-set(['IncomePerYear', 'TotalSatisfaction', 'PromotionRate', 'LongTimeNoPromotion','AgeStartedWorking', 'YearsInOtherCompanies', 'CompanyChangeRate']))
print(len(features_novas))
features_novas
# Out:
# 23
# ['Burnout',
#  'CargoAlto_HorasExtras',
#  'SatisfacaoGeral',
#  'TempoComGestorProporcao',
#  'SalarioPorKm',
#  'ScoreEstabilidadeFormat',
#  'TempSemPromoPorTempComManager',
#  'TreinamentosPorTempodeCasa',
#  'ScoreEstab_Carreira',
#  'TempGestAtualPorTempodeCasa',
#  'AnosCargoSemPromocao',
#  'SalarioPorSatisf',
#  'YearsInRolePercCompany',
#  'SalarioPorSatisfacaoGeral',
#  'CompaniesPerYear',
#  'SatisfacaoPeloNivel',
#  'EstavelNaEmpresa',
#  'TempoCargoAtualPeloNivel',
#  'SalarioAjustadoPorCargo',
#  'SalarioPorTempodeCasa',
#  'SalarioPorNivelEdu',
#  'PercAnoEmpresaAtual',
#  'PromotionsPerYear']

# %%
plt.figure(figsize=(20, 16))
correlation_matrix = df[features_novas].corr()

mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
sns.heatmap(correlation_matrix, mask=mask, annot=True, fmt='.2f', cmap='coolwarm',
            square=True, linewidths=0.5, cbar_kws={"shrink": 0.8})

plt.title('Matriz de Correlação das Variáveis Numéricas', fontsize=16)
plt.tight_layout()
plt.show()

# %%
correlation_matrix
# Out:
#                                 Burnout  CargoAlto_HorasExtras  \
# Burnout                        1.000000               0.050254
# CargoAlto_HorasExtras          0.050254               1.000000
# SatisfacaoGeral               -0.196515               0.000488
# TempoComGestorProporcao        0.000697              -0.010188
# SalarioPorKm                  -0.000986               0.081578
# ScoreEstabilidadeFormat       -0.001240               0.045971
# TempSemPromoPorTempComManager -0.000333               0.016924
# TreinamentosPorTempodeCasa     0.000906              -0.044898
# ScoreEstab_Carreira           -0.001213               0.047194
# TempGestAtualPorTempodeCasa    0.000697              -0.010188
# AnosCargoSemPromocao          -0.000483               0.022078
# SalarioPorSatisf               0.173696               0.259374
# YearsInRolePercCompany         0.000887              -0.004429
# SalarioPorSatisfacaoGeral      0.094801               0.323702
# CompaniesPerYear               0.001776              -0.056946
# SatisfacaoPeloNivel           -0.084853              -0.250156
# EstavelNaEmpresa              -0.000535              -0.007435
# TempoCargoAtualPeloNivel       0.002327              -0.072041
# SalarioAjustadoPorCargo       -0.004302               0.090829
# SalarioPorTempodeCasa         -0.001026               0.018203
# SalarioPorNivelEdu            -0.002477              -0.045035
# PercAnoEmpresaAtual            0.004122              -0.078583
# PromotionsPerYear              0.000062              -0.027622
#
#                                SatisfacaoGeral  TempoComGestorProporcao  \
# Burnout                              -0.196515                 0.000697
# CargoAlto_HorasExtras                 0.000488                -0.010188
# SatisfacaoGeral                       1.000000                -0.000738
# TempoComGestorProporcao              -0.000738                 1.000000
# SalarioPorKm                         -0.000957                -0.003336
# ScoreEstabilidadeFormat              -0.001630                 0.050809
# TempSemPromoPorTempComManager         0.000679                -0.376441
# TreinamentosPorTempodeCasa            0.000133                -0.136893
# ScoreEstab_Carreira                  -0.001289                 0.047993
# TempGestAtualPorTempodeCasa          -0.000738                 1.000000
# AnosCargoSemPromocao                 -0.000175                 0.125870
# SalarioPorSatisf                     -0.593194                -0.010547
# YearsInRolePercCompany               -0.000583                 0.661991
# SalarioPorSatisfacaoGeral            -0.467407                -0.013322
# CompaniesPerYear                      0.001446                -0.081519
# SatisfacaoPeloNivel                   0.454318                 0.008287
# EstavelNaEmpresa                      0.000342                -0.063025
# TempoCargoAtualPeloNivel             -0.000393                 0.280932
# SalarioAjustadoPorCargo               0.000220                -0.010012
# SalarioPorTempodeCasa                 0.000851                -0.130151
# SalarioPorNivelEdu                    0.000358                -0.012477
# PercAnoEmpresaAtual                  -0.000707                -0.065237
# PromotionsPerYear                    -0.000354                -0.151052
#
#                                SalarioPorKm  ScoreEstabilidadeFormat  \
# Burnout                           -0.000986                -0.001240
# CargoAlto_HorasExtras              0.081578                 0.045971
# SatisfacaoGeral                   -0.000957                -0.001630
# TempoComGestorProporcao           -0.003336                 0.050809
# SalarioPorKm                       1.000000                 0.025754
# ScoreEstabilidadeFormat            0.025754                 1.000000
# TempSemPromoPorTempComManager      0.016151                 0.032041
# TreinamentosPorTempodeCasa        -0.043318                -0.097780
# ScoreEstab_Carreira                0.027017                 0.972904
# TempGestAtualPorTempodeCasa       -0.003336                 0.050809
# AnosCargoSemPromocao               0.018578                 0.020961
# SalarioPorSatisf                   0.156254                 0.084629
# YearsInRolePercCompany             0.001828                 0.061746
# SalarioPorSatisfacaoGeral          0.195186                 0.104592
# CompaniesPerYear                  -0.037926                -0.945304
# SatisfacaoPeloNivel               -0.159060                -0.069590
# EstavelNaEmpresa                  -0.001014                 0.467704
# TempoCargoAtualPeloNivel          -0.029497                 0.026401
# SalarioAjustadoPorCargo            0.147677                 0.086974
# SalarioPorTempodeCasa              0.000856                -0.068789
# SalarioPorNivelEdu                 0.009786                 0.077512
# PercAnoEmpresaAtual               -0.036348                 0.013840
# PromotionsPerYear                 -0.029396                -0.075647
#
#                                TempSemPromoPorTempComManager  \
# Burnout                                            -0.000333
# CargoAlto_HorasExtras                               0.016924
# SatisfacaoGeral                                     0.000679
# TempoComGestorProporcao                            -0.376441
# SalarioPorKm                                        0.016151
# ScoreEstabilidadeFormat                             0.032041
# TempSemPromoPorTempComManager                       1.000000
# TreinamentosPorTempodeCasa                         -0.273477
# ScoreEstab_Carreira                                 0.033324
# TempGestAtualPorTempodeCasa                        -0.376441
# AnosCargoSemPromocao                               -0.271621
# SalarioPorSatisf                                    0.051680
# YearsInRolePercCompany                             -0.136220
# SalarioPorSatisfacaoGeral                           0.064426
# CompaniesPerYear                                   -0.065489
# SatisfacaoPeloNivel                                -0.057148
# EstavelNaEmpresa                                    0.107217
# TempoCargoAtualPeloNivel                           -0.047046
# SalarioAjustadoPorCargo                             0.060449
# SalarioPorTempodeCasa                              -0.304119
# SalarioPorNivelEdu                                  0.048588
# PercAnoEmpresaAtual                                 0.223138
# PromotionsPerYear                                  -0.569368
#
#                                TreinamentosPorTempodeCasa  \
# Burnout                                          0.000906
# CargoAlto_HorasExtras                           -0.044898
# SatisfacaoGeral                                  0.000133
# TempoComGestorProporcao                         -0.136893
# SalarioPorKm                                    -0.043318
# ScoreEstabilidadeFormat                         -0.097780
# TempSemPromoPorTempComManager                   -0.273477
# TreinamentosPorTempodeCasa                       1.000000
# ScoreEstab_Carreira                             -0.100544
# TempGestAtualPorTempodeCasa                     -0.136893
# AnosCargoSemPromocao                            -0.278716
# SalarioPorSatisf                                -0.140768
# YearsInRolePercCompany                          -0.280394
# SalarioPorSatisfacaoGeral                       -0.176004
# CompaniesPerYear                                 0.191880
# SatisfacaoPeloNivel                              0.158880
# EstavelNaEmpresa                                -0.237927
# TempoCargoAtualPeloNivel                        -0.407812
# SalarioAjustadoPorCargo                         -0.161730
# SalarioPorTempodeCasa                            0.797464
# SalarioPorNivelEdu                              -0.130242
# PercAnoEmpresaAtual                             -0.560183
# PromotionsPerYear                                0.507966
#
#                                ScoreEstab_Carreira  \
# Burnout                                  -0.001213
# CargoAlto_HorasExtras                     0.047194
# SatisfacaoGeral                          -0.001289
# TempoComGestorProporcao                   0.047993
# SalarioPorKm                              0.027017
# ScoreEstabilidadeFormat                   0.972904
# TempSemPromoPorTempComManager             0.033324
# TreinamentosPorTempodeCasa               -0.100544
# ScoreEstab_Carreira                       1.000000
# TempGestAtualPorTempodeCasa               0.047993
# AnosCargoSemPromocao                      0.024174
# SalarioPorSatisf                          0.088660
# YearsInRolePercCompany                    0.060520
# SalarioPorSatisfacaoGeral                 0.109670
# CompaniesPerYear                         -0.970470
# SatisfacaoPeloNivel                      -0.074467
# EstavelNaEmpresa                          0.485457
# TempoCargoAtualPeloNivel                  0.028783
# SalarioAjustadoPorCargo                   0.091329
# SalarioPorTempodeCasa                    -0.070608
# SalarioPorNivelEdu                        0.081603
# PercAnoEmpresaAtual                       0.012923
# PromotionsPerYear                        -0.076800
#
#                                TempGestAtualPorTempodeCasa  ...  \
# Burnout                                           0.000697  ...
# CargoAlto_HorasExtras                            -0.010188  ...
# SatisfacaoGeral                                  -0.000738  ...
# TempoComGestorProporcao                           1.000000  ...
# SalarioPorKm                                     -0.003336  ...
# ScoreEstabilidadeFormat                           0.050809  ...
# TempSemPromoPorTempComManager                    -0.376441  ...
# TreinamentosPorTempodeCasa                       -0.136893  ...
# ScoreEstab_Carreira                               0.047993  ...
# TempGestAtualPorTempodeCasa                       1.000000  ...
# AnosCargoSemPromocao                              0.125870  ...
# SalarioPorSatisf                                 -0.010547  ...
# YearsInRolePercCompany                            0.661991  ...
# SalarioPorSatisfacaoGeral                        -0.013322  ...
# CompaniesPerYear                                 -0.081519  ...
# SatisfacaoPeloNivel                               0.008287  ...
# EstavelNaEmpresa                                 -0.063025  ...
# TempoCargoAtualPeloNivel                          0.280932  ...
# SalarioAjustadoPorCargo                          -0.010012  ...
# SalarioPorTempodeCasa                            -0.130151  ...
# SalarioPorNivelEdu                               -0.012477  ...
# PercAnoEmpresaAtual                              -0.065237  ...
# PromotionsPerYear                                -0.151052  ...
#
#                                SalarioPorSatisfacaoGeral  CompaniesPerYear  \
# Burnout                                         0.094801          0.001776
# CargoAlto_HorasExtras                           0.323702         -0.056946
# SatisfacaoGeral                                -0.467407          0.001446
# TempoComGestorProporcao                        -0.013322         -0.081519
# SalarioPorKm                                    0.195186         -0.037926
# ScoreEstabilidadeFormat                         0.104592         -0.945304
# TempSemPromoPorTempComManager                   0.064426         -0.065489
# TreinamentosPorTempodeCasa                     -0.176004          0.191880
# ScoreEstab_Carreira                             0.109670         -0.970470
# TempGestAtualPorTempodeCasa                    -0.013322         -0.081519
# AnosCargoSemPromocao                            0.080811         -0.052041
# SalarioPorSatisf                                0.916931         -0.123651
# YearsInRolePercCompany                          0.011010         -0.108879
# SalarioPorSatisfacaoGeral                       1.000000         -0.153380
# CompaniesPerYear                               -0.153380          1.000000
# SatisfacaoPeloNivel                            -0.822829          0.115836
# EstavelNaEmpresa                                0.001331         -0.427863
# TempoCargoAtualPeloNivel                       -0.110224         -0.073728
# SalarioAjustadoPorCargo                         0.578006         -0.132169
# SalarioPorTempodeCasa                          -0.002517          0.145211
# SalarioPorNivelEdu                              0.036871         -0.113640
# PercAnoEmpresaAtual                            -0.139672         -0.068037
# PromotionsPerYear                              -0.113753          0.144000
#
#                                SatisfacaoPeloNivel  EstavelNaEmpresa  \
# Burnout                                  -0.084853         -0.000535
# CargoAlto_HorasExtras                    -0.250156         -0.007435
# SatisfacaoGeral                           0.454318          0.000342
# TempoComGestorProporcao                   0.008287         -0.063025
# SalarioPorKm                             -0.159060         -0.001014
# ScoreEstabilidadeFormat                  -0.069590          0.467704
# TempSemPromoPorTempComManager            -0.057148          0.107217
# TreinamentosPorTempodeCasa                0.158880         -0.237927
# ScoreEstab_Carreira                      -0.074467          0.485457
# TempGestAtualPorTempodeCasa               0.008287         -0.063025
# AnosCargoSemPromocao                     -0.073109          0.150643
# SalarioPorSatisf                         -0.753208          0.001243
# YearsInRolePercCompany                   -0.015124          0.017722
# SalarioPorSatisfacaoGeral                -0.822829          0.001331
# CompaniesPerYear                          0.115836         -0.427863
# SatisfacaoPeloNivel                       1.000000         -0.007615
# EstavelNaEmpresa                         -0.007615          1.000000
# TempoCargoAtualPeloNivel                  0.163668          0.208450
# SalarioAjustadoPorCargo                  -0.229256          0.008879
# SalarioPorTempodeCasa                     0.004715         -0.278031
# SalarioPorNivelEdu                        0.162896          0.002928
# PercAnoEmpresaAtual                       0.080066          0.340284
# PromotionsPerYear                         0.102868         -0.145016
#
#                                TempoCargoAtualPeloNivel  \
# Burnout                                        0.002327
# CargoAlto_HorasExtras                         -0.072041
# SatisfacaoGeral                               -0.000393
# TempoComGestorProporcao                        0.280932
# SalarioPorKm                                  -0.029497
# ScoreEstabilidadeFormat                        0.026401
# TempSemPromoPorTempComManager                 -0.047046
# TreinamentosPorTempodeCasa                    -0.407812
# ScoreEstab_Carreira                            0.028783
# TempGestAtualPorTempodeCasa                    0.280932
# AnosCargoSemPromocao                           0.686184
# SalarioPorSatisf                              -0.087945
# YearsInRolePercCompany                         0.674719
# SalarioPorSatisfacaoGeral                     -0.110224
# CompaniesPerYear                              -0.073728
# SatisfacaoPeloNivel                            0.163668
# EstavelNaEmpresa                               0.208450
# TempoCargoAtualPeloNivel                       1.000000
# SalarioAjustadoPorCargo                        0.040107
# SalarioPorTempodeCasa                         -0.484999
# SalarioPorNivelEdu                             0.169524
# PercAnoEmpresaAtual                            0.452941
# PromotionsPerYear                             -0.270857
#
#                                SalarioAjustadoPorCargo  SalarioPorTempodeCasa  \
# Burnout                                      -0.004302              -0.001026
# CargoAlto_HorasExtras                         0.090829               0.018203
# SatisfacaoGeral                               0.000220               0.000851
# TempoComGestorProporcao                      -0.010012              -0.130151
# SalarioPorKm                                  0.147677               0.000856
# ScoreEstabilidadeFormat                       0.086974              -0.068789
# TempSemPromoPorTempComManager                 0.060449              -0.304119
# TreinamentosPorTempodeCasa                   -0.161730               0.797464
# ScoreEstab_Carreira                           0.091329              -0.070608
# TempGestAtualPorTempodeCasa                  -0.010012              -0.130151
# AnosCargoSemPromocao                          0.073114              -0.315543
# SalarioPorSatisf                              0.463078              -0.002389
# YearsInRolePercCompany                        0.013942              -0.293095
# SalarioPorSatisfacaoGeral                     0.578006              -0.002517
# CompaniesPerYear                             -0.132169               0.145211
# SatisfacaoPeloNivel                          -0.229256               0.004715
# EstavelNaEmpresa                              0.008879              -0.278031
# TempoCargoAtualPeloNivel                      0.040107              -0.484999
# SalarioAjustadoPorCargo                       1.000000              -0.018966
# SalarioPorTempodeCasa                        -0.018966               1.000000
# SalarioPorNivelEdu                            0.374431              -0.117356
# PercAnoEmpresaAtual                          -0.107966              -0.679243
# PromotionsPerYear                            -0.105299               0.554569
#
#                                SalarioPorNivelEdu  PercAnoEmpresaAtual  \
# Burnout                                 -0.002477             0.004122
# CargoAlto_HorasExtras                   -0.045035            -0.078583
# SatisfacaoGeral                          0.000358            -0.000707
# TempoComGestorProporcao                 -0.012477            -0.065237
# SalarioPorKm                             0.009786            -0.036348
# ScoreEstabilidadeFormat                  0.077512             0.013840
# TempSemPromoPorTempComManager            0.048588             0.223138
# TreinamentosPorTempodeCasa              -0.130242            -0.560183
# ScoreEstab_Carreira                      0.081603             0.012923
# TempGestAtualPorTempodeCasa             -0.012477            -0.065237
# AnosCargoSemPromocao                     0.060819             0.285292
# SalarioPorSatisf                         0.030018            -0.111657
# YearsInRolePercCompany                   0.006455             0.057864
# SalarioPorSatisfacaoGeral                0.036871            -0.139672
# CompaniesPerYear                        -0.113640            -0.068037
# SatisfacaoPeloNivel                      0.162896             0.080066
# EstavelNaEmpresa                         0.002928             0.340284
# TempoCargoAtualPeloNivel                 0.169524             0.452941
# SalarioAjustadoPorCargo                  0.374431            -0.107966
# SalarioPorTempodeCasa                   -0.117356            -0.679243
# SalarioPorNivelEdu                       1.000000            -0.106064
# PercAnoEmpresaAtual                     -0.106064             1.000000
# PromotionsPerYear                       -0.083965            -0.356479
#
#                                PromotionsPerYear
# Burnout                                 0.000062
# CargoAlto_HorasExtras                  -0.027622
# SatisfacaoGeral                        -0.000354
# TempoComGestorProporcao                -0.151052
# SalarioPorKm                           -0.029396
# ScoreEstabilidadeFormat                -0.075647
# TempSemPromoPorTempComManager          -0.569368
# TreinamentosPorTempodeCasa              0.507966
# ScoreEstab_Carreira                    -0.076800
# TempGestAtualPorTempodeCasa            -0.151052
# AnosCargoSemPromocao                    0.208130
# SalarioPorSatisf                       -0.091112
# YearsInRolePercCompany                 -0.247040
# SalarioPorSatisfacaoGeral              -0.113753
# CompaniesPerYear                        0.144000
# SatisfacaoPeloNivel                     0.102868
# EstavelNaEmpresa                       -0.145016
# TempoCargoAtualPeloNivel               -0.270857
# SalarioAjustadoPorCargo                -0.105299
# SalarioPorTempodeCasa                   0.554569
# SalarioPorNivelEdu                     -0.083965
# PercAnoEmpresaAtual                    -0.356479
# PromotionsPerYear                       1.000000
#
# [23 rows x 23 columns]

# %%
corr_pairs = correlation_matrix.abs().where(~np.eye(correlation_matrix.shape[0], dtype=bool))
high_corr = corr_pairs.stack().reset_index()
high_corr.columns = ['Var1', 'Var2', 'Correlation']
high_corr = high_corr[high_corr['Correlation'] > 0.6].sort_values('Correlation', ascending=False)
high_corr
# Out:
#                             Var1                         Var2  Correlation
# 74       TempoComGestorProporcao  TempGestAtualPorTempodeCasa     1.000000
# 201  TempGestAtualPorTempodeCasa      TempoComGestorProporcao     1.000000
# 181          ScoreEstab_Carreira      ScoreEstabilidadeFormat     0.972904
# 117      ScoreEstabilidadeFormat          ScoreEstab_Carreira     0.972904
# 189          ScoreEstab_Carreira             CompaniesPerYear     0.970470
# 316             CompaniesPerYear          ScoreEstab_Carreira     0.970470
# 123      ScoreEstabilidadeFormat             CompaniesPerYear     0.945304
# 313             CompaniesPerYear      ScoreEstabilidadeFormat     0.945304
# 254             SalarioPorSatisf    SalarioPorSatisfacaoGeral     0.916931
# 297    SalarioPorSatisfacaoGeral             SalarioPorSatisf     0.916931
# 343          SatisfacaoPeloNivel    SalarioPorSatisfacaoGeral     0.822829
# 300    SalarioPorSatisfacaoGeral          SatisfacaoPeloNivel     0.822829
# 172   TreinamentosPorTempodeCasa        SalarioPorTempodeCasa     0.797464
# 425        SalarioPorTempodeCasa   TreinamentosPorTempodeCasa     0.797464
# 341          SatisfacaoPeloNivel             SalarioPorSatisf     0.753208
# 256             SalarioPorSatisf          SatisfacaoPeloNivel     0.753208
# 384     TempoCargoAtualPeloNivel         AnosCargoSemPromocao     0.686184
# 236         AnosCargoSemPromocao     TempoCargoAtualPeloNivel     0.686184
# 438        SalarioPorTempodeCasa          PercAnoEmpresaAtual     0.679243
# 481          PercAnoEmpresaAtual        SalarioPorTempodeCasa     0.679243
# 280       YearsInRolePercCompany     TempoCargoAtualPeloNivel     0.674719
# 386     TempoCargoAtualPeloNivel       YearsInRolePercCompany     0.674719
# 77       TempoComGestorProporcao       YearsInRolePercCompany     0.661991
# 267       YearsInRolePercCompany      TempoComGestorProporcao     0.661991
# 209  TempGestAtualPorTempodeCasa       YearsInRolePercCompany     0.661991
# 273       YearsInRolePercCompany  TempGestAtualPorTempodeCasa     0.661991

# %%
correlation_matrix = df[features_novas].corr().abs()

np.fill_diagonal(correlation_matrix.values, 0)
features_fortes = correlation_matrix.columns[(correlation_matrix > 0.6).any()].tolist()

correlation_matrix_filtrada = df[features_fortes].corr()

plt.figure(figsize=(12, 10))
mask = np.triu(np.ones_like(correlation_matrix_filtrada, dtype=bool))
sns.heatmap(correlation_matrix_filtrada, mask=mask, annot=True, fmt='.2f', cmap='coolwarm',
            square=True, linewidths=0.5, cbar_kws={"shrink": 0.8})
plt.title('Correlação > 0.6 entre Features Novas', fontsize=16)
plt.tight_layout()
plt.show()

# %%
df.to_csv('../data/ibm_hr_dataset_com_features.csv', index=False)
